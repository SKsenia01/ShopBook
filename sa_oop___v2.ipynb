# %% [markdown]
# <a href="https://colab.research.google.com/github/SKsenia01/ShopBook/blob/main/sa_oop___v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Интернет магазин.
#
# ## Этап 1.
#
# * Создать класс Товар, имеющий переменные имя, цена, рейтинг.
# * Создать класс Категория, имеющий переменные имя и массив товаров. Создать несколько объектов класса Категория.
# * Создать класс Basket, содержащий массив купленных товаров.
# * Создать класс User, содержащий логин, пароль и объект класса Basket. Создать объект класса User.
#
# ## Этап 1.1.
# * Создать генераторы данных для конкретного магазина. Должны приближенно соответствовать реальным категориям и наименованием
#
# ## Этап 2.
#
# * Аутентификация пользователя. Пользователь вводит логин и пароль с клавиатуры.
# * Просмотр списка каталогов товаров. (4-6 категорий)
# * Просмотр списка товаров определенного каталога. (15-20 товаров в категории)
# * Выбор товара в корзину.
# * Покупка товаров, находящихся в корзине.
# * Можете добавить свои операции или изменить что-то на свой вкус.

# %% [markdown]
# Выбор вариантов магазина:
#
# * Продуктовый магазин
#
# * Бытовая техника
#
# * Хозяйственный магазин
#
# * Стройматериалы

# %%
#создаю класс "Продукт/Товар"
class Product: 
    def __init__(self, nameProduct: str, price: float, rating: float):

        self.nameProduct = nameProduct #наименование товара 
        self.price = price  #цена 
        self.rating = rating #рейтинг


#создаю класс "Категория"
#в данном классе создаю несколько объектов, наполненных товарами (решила, что обойдусь без генератора)
class Category: 

    def __init__(self, nameCategory, *Product):  
        self.nameCategory = nameCategory #наименование категории 
        self.goodsCategory = Product #товар

    def display_info(self):
        print(f"nameCategory: {self.nameCategory} ")
        for x in self.goodsCategory:
          print(x.nameProduct, x.price,"рублей", x.rating)

Books = Category("Книги", 
                 Product("Алиса в стране чудес", 200, 8.9),
                 Product("Азбука", 600, 9.9),
                 Product("Война и мир", 1200, 7.9),
                 Product("Герой нашего времени", 500, 8.9),
                 Product("Властелин колец", 1600, 9.3),
                 Product("Шоколад", 500, 8.9),
                 Product("Игра в бисер", 550, 8.9),
                 Product("На западном фронте без перемен", 340, 9.7),
                 Product("Искра жизни", 445, 9.7),
                 Product("Хоббит", 710, 8.6),
                 Product("Список Шиндлера", 900, 9.8),
                 Product("Ведьмак, ч.1", 400, 8.9),
                 Product("Ведьмак, ч.2", 400, 8.6),
                 Product("Темные аллеи", 200, 7.6),
                 Product("Капитанская дочка", 150, 7.7))
#Books.display_info()      
#print(" ")

Toys = Category("Игрушки",
                Product("Машинка", 150, 4.9),
                Product("Плюшевый мишка", 700, 4.9),
                Product("Паззлы", 900, 8.9),
                Product("Зайчик", 200, 8.2),
                Product("Алиас", 300, 6.7),  
                Product("Водный пистолет", 400, 7.3),
                Product("Алмазная мозайка", 800, 9.2),
                Product("Кукла", 500, 6.2),
                Product("Кубики", 600, 7.8),
                Product("Самосвал", 900, 3.2), 
                Product("Домино", 400, 7.2), 
                Product("Раскраска", 200, 7.1),
                Product("Шашки", 300, 6.1),
                Product("Пластилин", 150, 8.1),
                Product("Игрушка-антистресс", 140, 4.1))                     
#Toys.display_info()  
#print(" ")

OfficeGoogs = Category("Канцелярские товары",
                       Product("Шариковая ручка", 40, 7.3), 
                       Product("Карандаш", 60, 8.9),
                       Product("Тетрадь в клетку, 40л", 30, 4.3),
                       Product("Тетрадь в линейку, 40л", 25, 5.2),
                       Product("Пенал", 300, 7.2), 
                       Product("Ластик", 20, 8.2),
                       Product("Гелевая ручка", 50, 8.1),
                       Product("Ежедневник", 900, 9.1),
                       Product("Стикеры", 200, 8.3),
                       Product("Папка для бумаг", 150, 7.3),
                       Product("Конверт", 30, 7.7),
                       Product("Набор файлов", 170, 9.1),
                       Product("Блокнот", 80, 5.1),
                       Product("Школьный дневник", 200, 6.9),
                       Product("Альбом", 170, 7.1))
#OfficeGoogs.display_info() 
#print(" ")

Souvenirs = Category("Сувениры", 
                     Product("Магнит", 200, 8.3), 
                     Product("Открытка", 60, 6.2),
                     Product("Календарь", 700, 9.1),
                     Product("Подарочный пакет", 100, 8.1),
                     Product("Кружка", 300, 9.1),
                     Product("Мозайка", 500, 7.1),
                     Product("Значок", 200, 8.5),
                     Product("Постер", 400, 7.6),
                     Product("Путеводитель", 700, 9.1),
                     Product("Колокольчик", 600, 8.8),
                     Product("Игральные карты", 500, 9.2),
                     Product("Настольные часы", 900, 7.2),
                     Product("Фоторамка", 750, 6.3),
                     Product("Фотоальбом", 950, 7.5),
                     Product("Карманное зеркальце", 400, 7.4))
#Souvenirs.display_info()
#print(" ")

SweetThings = Category("Сладости", 
                       Product("Мармелад", 300, 9.3),
                       Product("Шоколад 'Книжный'", 280, 9.2),
                       Product("Леденцы", 150, 7.1),
                       Product("Конфеты", 150, 7.1),
                       Product("Жевательная резинка", 50, 7.3),
                       Product("Шоколадный батончик", 80, 7.9),
                       Product("Шоколад 'Клёвый'", 200, 9.1),
                       Product("Лакричные конфеты", 300, 8.1),
                       Product("Лимонад", 150, 9.2),
                       Product("Зефир", 180, 7.2),
                       Product("Пастила", 110, 6.1),
                       Product("Арахис в шоколадной глазури", 190, 8.1),
                       Product("Фруктовые чипсы", 220, 6.3),
                       Product("Сахарные палочки", 190, 9.3),
                       Product("Чупа-чупс", 30, 9.6))
#SweetThings.display_info()
#print(" ")

#создаю класс "Корзина"
class Basket:
    products = []
    def __init__(self):
        self.products = []

    #метод, отвечающий за добавление товаров в корзину
    def setProductToBasket(self, product: Product):
        self.products.append(product) 

    #метод, отвечающий за просмотр товаров в корзину
    def showProductsInBasket(self):
      for x in self.products: 
       print(x.nameProduct, x.price, x.rating)

    #метод, отвечающий за оплату покупки
    def actionWithBasket(self):
     print("для оплаты покупки введите 1, для возврата на предыдущую страницу введите 0")
     position: int = 0
     sumPokypki: float = 0
     for x in basket.products:
      position = position + 1  
      sumPokypki = sumPokypki + x.price # сумма покупки
      print(position,". ", x.nameProduct, x.price," рублей", " Рейтинг ", x.rating)
     print("Сумма покупки = ", sumPokypki, "рублей")
     actionBasket = int(input())
     if (actionBasket != 0):
        print("Покупка оплачена. Вы автоматически вернётесь на предыдущую страницу")

#создаю класс "Пользователь"
class User:
    def __init__(self, login: str, password: str, basket):
        self.login = login 
        self.password = password 
        self.basket = basket

    def display_info(self):
        print(f"login: {self.login} password: {self.password}")

#Создаю несколько объектов класса
User1 = User("mashkap7", "5678941", Basket())
#User1.display_info()  

User2 = User("petrov1", "6978342", Basket())
#User2.display_info()         

User3 = User("grishaN", "1234445", Basket())
#User3.display_info()

User4 = User("mama567", "1234789", Basket())
#User4.display_info()

User5 = User("papa312", "9874321", Basket())
#User5.display_info()

# Авторизацию делаю при помощи словаря (т.к. логины уникальны и так проще работать с кодом)
# В роли ключа - логин, в роли значения - User
mapUsers = {}
mapUsers[User1.login]= User1
mapUsers[User2.login]= User2
mapUsers[User3.login]= User3
mapUsers[User4.login]= User4
mapUsers[User5.login]= User5

#Иммитация базы данных, где уже есть продукты
productdata = []
productdata.append(Books)
productdata.append(Toys)
productdata.append(OfficeGoogs)
productdata.append(Souvenirs)
productdata.append(SweetThings)



# 1.Аутентификация 

print("Введите свой логин и пароль для входа в систему") 

# Первый цикл нужен для того, чтобы по выходу из аутентификации, попасть на нее снова. Выход происходит со страницы с категориями
while True:
 print("Чтобы выйти введите 0")

 print("Введите логин")
 login = str(input())
 if login=="0":
   break

# Осуществляю поиск пользователя по ключу
 userAuntificate = mapUsers.get(login)
# Если пользователя с таким логином не существует, то аутентификация не пройдет (т.к. данные отсутствуют)
 if(userAuntificate == None):
   print("Такого пользователя нет в системе. Попробуйте еще раз")
   continue
 print("Введите пароль")
 password = input()
 if (mapUsers.get(login).password!=password):
   print("Пароль введен неверно")
   continue



# 2.Работа с корзиной

# Пользователь найден. Теперь необходимо подключить корзину, которая принадлежит пользователю
 basket = userAuntificate.basket;
# Необходим цикл, так как после выбора продукта в выбранной категории мы можем захотеть еще что-то выбрать из другой категории
 while True:  
  print("Выберите категорию. Чтобы поменять пользователя введите 0, для выбора коризины введите -1")
  num: int = 0
  # вывожу категорию
  for i in productdata:
    num = num + 1
    print(num ,". ", i.nameCategory)
  num = 0
  # выбираю категорию
  categoryNumber = int(input())
  # Работаю с выбранной категорией. В противном случае, перехожу в корзину или на аутентификацию
  if categoryNumber != 0 and categoryNumber !=-1:
   print("Список товаров:")

# После выбора категории работаю со списком товаров, принадлежащих выбранной категории
# Снова необходим цикл, т.к. может быть выбран не один товар из предложенного списка
   while True :
    print("Выберите товар из списка. Чтобы вернуться в раздел категорий введите 0, для выбора коризины введи -1 ")
    for x in productdata[categoryNumber-1].goodsCategory: # "-1" необходим,т.к. отсчет в массиве идет с 0, а у нас нумерация товаров идет с 1 
     num= num + 1
     print(num,". ", x.nameProduct, x.price," рублей", " Рейтинг ", x.rating)
    # выбираю товар
    productNumber = int(input())
    if (productNumber == 0):
      break
    if productNumber == -1:
     basket.actionWithBasket()  
    else:  
      basket.setProductToBasket(productdata[categoryNumber-1].goodsCategory[productNumber-1])
    num = 0
  else:
    # Переходим в корзину если было выбрано -1 в разделе категории
    if categoryNumber == -1:
      basket.actionWithBasket()
      continue
    else:
      # break нам нужен, чтобы выйти с цикла категорий и перейти на аутентификацию
      break
# Out:
# Введите свой логин и пароль для входа в систему
# Чтобы выйти введите 0
# Введите логин
# mama567
# Введите пароль
# 1234789
# Выберите категорию. Чтобы поменять пользователя введите 0, для выбора коризины введите -1
# 1 .  Книги
# 2 .  Игрушки
# 3 .  Канцелярские товары
# 4 .  Сувениры
# 5 .  Сладости
# 2
# Список товаров:
# Выберите товар из списка. Чтобы вернуться в раздел категорий введите 0, для выбора коризины введи -1
# 1 .  Машинка 150  рублей  Рейтинг  4.9
# 2 .  Плюшевый мишка 700  рублей  Рейтинг  4.9
# 3 .  Паззлы 900  рублей  Рейтинг  8.9
# 4 .  Зайчик 200  рублей  Рейтинг  8.2
# 5 .  Алиас 300  рублей  Рейтинг  6.7
# 6 .  Водный пистолет 400  рублей  Рейтинг  7.3
# 7 .  Алмазная мозайка 800  рублей  Рейтинг  9.2
# 8 .  Кукла 500  рублей  Рейтинг  6.2
# 9 .  Кубики 600  рублей  Рейтинг  7.8
# 10 .  Самосвал 900  рублей  Рейтинг  3.2
# 11 .  Домино 400  рублей  Рейтинг  7.2
# 12 .  Раскраска 200  рублей  Рейтинг  7.1
# 13 .  Шашки 300  рублей  Рейтинг  6.1
# ...
